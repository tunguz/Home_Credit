# %%
import numpy as np
import pandas as pd
import gc
import time

from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
from tqdm import tqdm

import warnings
from time import time
import xgboost as xgb
xgb.__version__
# Out:
# '1.3.3'

# %%
# %%time
train = pd.read_csv('../input/train_1830.csv')
# Out:
# CPU times: user 43.2 s, sys: 4.08 s, total: 47.3 s
# Wall time: 47.3 s

# %%
application_train = pd.read_csv('../input/application_train.csv')
target = application_train.TARGET.values

# %%
good_features = train.columns[2:]

# %%
params = {
    'objective' : "binary:logistic",
    'booster' : "gbtree",
    'eval_metric' : "auc",
    'nthread' : -1,
    'eta' : 0.001,
    'max_depth' : 6,
    'min_child_weight' : 22,
    'gamma' :0,
    'subsample' : 0.7,
    'colsample_bytree' : 0.7,
    'colsample_bylevel' : 0.675,
    'alpha' : 0.00,
    'lambda' : 0.00,
    'tree_method' : 'gpu_hist',
    'predictor': 'gpu_predictor',
    #'scale_pos_weights' : 1,
    #'nrounds' : 100000,
    #'verbose_eval': 1250,
    'seed' : 19947
}

# %%
# %%time
start_time = time()
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].values[train_index], train[good_features].values[test_index]
        y_train, y_val = target[train_index], target[test_index]
        xgtrain = xgb.DMatrix(xgtrain, label = y_train ) 
        xgval = xgb.DMatrix(xgval, label = y_val ) 
        watchlist = [(xgtrain, 'train'), (xgval, 'eval')]
        clf = xgb.train(params, xgtrain, num_boost_round=100000, evals=watchlist, 
                verbose_eval=100, 
                early_stopping_rounds = 1500)
        
        #preds = clf.predict(xgtest)
        ypred = clf.predict(xgval, ntree_limit=clf.best_ntree_limit)
        #y_oof[test_index] = ypred
        #preds_total += preds
        #np.save("preds_hist_"+str(i), preds)
        #p.save("oof_preds_hist_"+str(i), ypred)
        print('Time elapsed:', time()-start_time)
        #clf.save_model('xgb_gpu_hist_1812_2_fold_'+str(i)+'.model')
        del clf
        gc.collect()
        i +=1
        print('Fold AUC:', roc_auc_score(y_val, ypred))
        
        break
# Out:
# 1
# [0]	train-auc:0.75684	eval-auc:0.74114
# [100]	train-auc:0.77873	eval-auc:0.75932
# [200]	train-auc:0.77981	eval-auc:0.76004
# [300]	train-auc:0.78063	eval-auc:0.76049
# [400]	train-auc:0.78148	eval-auc:0.76109
# [500]	train-auc:0.78225	eval-auc:0.76157
# [600]	train-auc:0.78293	eval-auc:0.76205
# [700]	train-auc:0.78361	eval-auc:0.76249
# [800]	train-auc:0.78415	eval-auc:0.76277
# [900]	train-auc:0.78482	eval-auc:0.76319
# [1000]	train-auc:0.78541	eval-auc:0.76363
# [1100]	train-auc:0.78602	eval-auc:0.76405
# [1200]	train-auc:0.78664	eval-auc:0.76445
# [1300]	train-auc:0.78734	eval-auc:0.76489
# [1400]	train-auc:0.78800	eval-auc:0.76530
# [1500]	train-auc:0.78870	eval-auc:0.76571
# [1600]	train-auc:0.78936	eval-auc:0.76610
# [1700]	train-auc:0.79010	eval-auc:0.76648
# [1800]	train-auc:0.79081	eval-auc:0.76687
# [1900]	train-auc:0.79155	eval-auc:0.76726
# [2000]	train-auc:0.79230	eval-auc:0.76768
# [2100]	train-auc:0.79310	eval-auc:0.76815
# [2200]	train-auc:0.79384	eval-auc:0.76855
# [2300]	train-auc:0.79459	eval-auc:0.76899
# [2400]	train-auc:0.79534	eval-auc:0.76942
# [2500]	train-auc:0.79614	eval-auc:0.76989
# [2600]	train-auc:0.79696	eval-auc:0.77035
# [2700]	train-auc:0.79780	eval-auc:0.77079
# [2800]	train-auc:0.79863	eval-auc:0.77125
# [2900]	train-auc:0.79950	eval-auc:0.77174
# [3000]	train-auc:0.80035	eval-auc:0.77223
# [3100]	train-auc:0.80117	eval-auc:0.77270
# [3200]	train-auc:0.80206	eval-auc:0.77320
# [3300]	train-auc:0.80296	eval-auc:0.77371
# [3400]	train-auc:0.80388	eval-auc:0.77424
# [3500]	train-auc:0.80478	eval-auc:0.77473
# [3600]	train-auc:0.80566	eval-auc:0.77521
# [3700]	train-auc:0.80649	eval-auc:0.77564
# [3800]	train-auc:0.80737	eval-auc:0.77612
# [3900]	train-auc:0.80822	eval-auc:0.77656
# [4000]	train-auc:0.80908	eval-auc:0.77699
# [4100]	train-auc:0.80995	eval-auc:0.77745
# [4200]	train-auc:0.81076	eval-auc:0.77786
# [4300]	train-auc:0.81162	eval-auc:0.77831
# [4400]	train-auc:0.81248	eval-auc:0.77876
# [4500]	train-auc:0.81335	eval-auc:0.77921
# [4600]	train-auc:0.81420	eval-auc:0.77965
# [4700]	train-auc:0.81504	eval-auc:0.78008
# [4800]	train-auc:0.81589	eval-auc:0.78052
# [4900]	train-auc:0.81673	eval-auc:0.78094
# [5000]	train-auc:0.81758	eval-auc:0.78137
# [5100]	train-auc:0.81840	eval-auc:0.78179
# [5200]	train-auc:0.81924	eval-auc:0.78220
# [5300]	train-auc:0.82004	eval-auc:0.78259
# [5400]	train-auc:0.82081	eval-auc:0.78296
# [5500]	train-auc:0.82156	eval-auc:0.78332
# [5600]	train-auc:0.82229	eval-auc:0.78366
# [5700]	train-auc:0.82302	eval-auc:0.78400
# [5800]	train-auc:0.82374	eval-auc:0.78433
# [5900]	train-auc:0.82445	eval-auc:0.78465
# [6000]	train-auc:0.82514	eval-auc:0.78495
# [6100]	train-auc:0.82581	eval-auc:0.78525
# [6200]	train-auc:0.82646	eval-auc:0.78553
# [6300]	train-auc:0.82707	eval-auc:0.78580
# [6400]	train-auc:0.82768	eval-auc:0.78607
# [6500]	train-auc:0.82827	eval-auc:0.78632
# [6600]	train-auc:0.82889	eval-auc:0.78656
# [6700]	train-auc:0.82946	eval-auc:0.78681
# [6800]	train-auc:0.83005	eval-auc:0.78704
# [6900]	train-auc:0.83059	eval-auc:0.78726
# [7000]	train-auc:0.83115	eval-auc:0.78746
# [7100]	train-auc:0.83169	eval-auc:0.78768
# [7200]	train-auc:0.83222	eval-auc:0.78789
# [7300]	train-auc:0.83275	eval-auc:0.78810
# [7400]	train-auc:0.83327	eval-auc:0.78829
# [7500]	train-auc:0.83379	eval-auc:0.78848
# [7600]	train-auc:0.83428	eval-auc:0.78867
# [7700]	train-auc:0.83478	eval-auc:0.78884
# [7800]	train-auc:0.83529	eval-auc:0.78902
# [7900]	train-auc:0.83576	eval-auc:0.78919
# [8000]	train-auc:0.83625	eval-auc:0.78936
# [8100]	train-auc:0.83671	eval-auc:0.78952
# [8200]	train-auc:0.83720	eval-auc:0.78967
# [8300]	train-auc:0.83766	eval-auc:0.78982
# [8400]	train-auc:0.83813	eval-auc:0.78998
# [8500]	train-auc:0.83860	eval-auc:0.79013
# [8600]	train-auc:0.83905	eval-auc:0.79027
# [8700]	train-auc:0.83950	eval-auc:0.79041
# [8800]	train-auc:0.83993	eval-auc:0.79055
# [8900]	train-auc:0.84038	eval-auc:0.79069
# [9000]	train-auc:0.84081	eval-auc:0.79082
# [9100]	train-auc:0.84123	eval-auc:0.79094
# [9200]	train-auc:0.84164	eval-auc:0.79106
# [9300]	train-auc:0.84204	eval-auc:0.79119
# [9400]	train-auc:0.84246	eval-auc:0.79131
# [9500]	train-auc:0.84285	eval-auc:0.79142
# [9600]	train-auc:0.84325	eval-auc:0.79153
# [9700]	train-auc:0.84367	eval-auc:0.79163
# [9800]	train-auc:0.84407	eval-auc:0.79173
# [9900]	train-auc:0.84446	eval-auc:0.79184
# [10000]	train-auc:0.84483	eval-auc:0.79193
# [10100]	train-auc:0.84522	eval-auc:0.79202
# [10200]	train-auc:0.84560	eval-auc:0.79215
# [10300]	train-auc:0.84599	eval-auc:0.79224
# [10400]	train-auc:0.84638	eval-auc:0.79233
# [10500]	train-auc:0.84677	eval-auc:0.79243
# [10600]	train-auc:0.84713	eval-auc:0.79252
# [10700]	train-auc:0.84750	eval-auc:0.79262
# [10800]	train-auc:0.84788	eval-auc:0.79271
# [10900]	train-auc:0.84826	eval-auc:0.79280
# [11000]	train-auc:0.84864	eval-auc:0.79289
# [11100]	train-auc:0.84901	eval-auc:0.79299
# [11200]	train-auc:0.84937	eval-auc:0.79305
# [11300]	train-auc:0.84972	eval-auc:0.79313
# [11400]	train-auc:0.85010	eval-auc:0.79321
# [11500]	train-auc:0.85044	eval-auc:0.79329
# [11600]	train-auc:0.85077	eval-auc:0.79336
# [11700]	train-auc:0.85113	eval-auc:0.79343
# [11800]	train-auc:0.85150	eval-auc:0.79350
# [11900]	train-auc:0.85181	eval-auc:0.79357
# [12000]	train-auc:0.85217	eval-auc:0.79365
# [12100]	train-auc:0.85251	eval-auc:0.79371
# [12200]	train-auc:0.85284	eval-auc:0.79378
# [12300]	train-auc:0.85317	eval-auc:0.79385
# [12400]	train-auc:0.85350	eval-auc:0.79392
# [12500]	train-auc:0.85384	eval-auc:0.79398
# [12600]	train-auc:0.85420	eval-auc:0.79405
# [12700]	train-auc:0.85451	eval-auc:0.79411
# [12800]	train-auc:0.85485	eval-auc:0.79417
# [12900]	train-auc:0.85519	eval-auc:0.79423
# [13000]	train-auc:0.85552	eval-auc:0.79430
# [13100]	train-auc:0.85585	eval-auc:0.79437
# [13200]	train-auc:0.85618	eval-auc:0.79443
# [13300]	train-auc:0.85653	eval-auc:0.79450
# [13400]	train-auc:0.85685	eval-auc:0.79455
# [13500]	train-auc:0.85718	eval-auc:0.79460
# [13600]	train-auc:0.85748	eval-auc:0.79466
# [13700]	train-auc:0.85779	eval-auc:0.79472
# [13800]	train-auc:0.85812	eval-auc:0.79480
# [13900]	train-auc:0.85844	eval-auc:0.79486
# [14000]	train-auc:0.85874	eval-auc:0.79491
# [14100]	train-auc:0.85906	eval-auc:0.79496
# [14200]	train-auc:0.85938	eval-auc:0.79503
# [14300]	train-auc:0.85968	eval-auc:0.79508
# [14400]	train-auc:0.85998	eval-auc:0.79514
# [14500]	train-auc:0.86028	eval-auc:0.79518
# [14600]	train-auc:0.86058	eval-auc:0.79523
# [14700]	train-auc:0.86088	eval-auc:0.79529
# [14800]	train-auc:0.86119	eval-auc:0.79534
# [14900]	train-auc:0.86149	eval-auc:0.79538
# [15000]	train-auc:0.86178	eval-auc:0.79543
# [15100]	train-auc:0.86204	eval-auc:0.79546
# [15200]	train-auc:0.86234	eval-auc:0.79550
# [15300]	train-auc:0.86264	eval-auc:0.79555
# [15400]	train-auc:0.86294	eval-auc:0.79559
# [15500]	train-auc:0.86324	eval-auc:0.79565
# [15600]	train-auc:0.86355	eval-auc:0.79570
# [15700]	train-auc:0.86383	eval-auc:0.79573
# [15800]	train-auc:0.86411	eval-auc:0.79576
# [15900]	train-auc:0.86441	eval-auc:0.79579
# [16000]	train-auc:0.86468	eval-auc:0.79583
# [16100]	train-auc:0.86496	eval-auc:0.79587
# [16200]	train-auc:0.86526	eval-auc:0.79590
# [16300]	train-auc:0.86555	eval-auc:0.79593
# [16400]	train-auc:0.86584	eval-auc:0.79597
# [16500]	train-auc:0.86613	eval-auc:0.79601
# [16600]	train-auc:0.86640	eval-auc:0.79605
# [16700]	train-auc:0.86668	eval-auc:0.79609
# [16800]	train-auc:0.86696	eval-auc:0.79612
# [16900]	train-auc:0.86724	eval-auc:0.79616
# [17000]	train-auc:0.86750	eval-auc:0.79618
# [17100]	train-auc:0.86778	eval-auc:0.79622
# [17200]	train-auc:0.86805	eval-auc:0.79625
# [17300]	train-auc:0.86833	eval-auc:0.79627
# [17400]	train-auc:0.86861	eval-auc:0.79631
# [17500]	train-auc:0.86890	eval-auc:0.79634
# [17600]	train-auc:0.86917	eval-auc:0.79637
# [17700]	train-auc:0.86947	eval-auc:0.79641
# [17800]	train-auc:0.86975	eval-auc:0.79644
# [17900]	train-auc:0.87001	eval-auc:0.79647
# [18000]	train-auc:0.87028	eval-auc:0.79649
# [18100]	train-auc:0.87055	eval-auc:0.79652
# [18200]	train-auc:0.87082	eval-auc:0.79656
# [18300]	train-auc:0.87108	eval-auc:0.79659
# [18400]	train-auc:0.87135	eval-auc:0.79662
# [18500]	train-auc:0.87161	eval-auc:0.79664
# [18600]	train-auc:0.87188	eval-auc:0.79667
# [18700]	train-auc:0.87215	eval-auc:0.79670
# [18800]	train-auc:0.87240	eval-auc:0.79672
# [18900]	train-auc:0.87264	eval-auc:0.79676
# [19000]	train-auc:0.87289	eval-auc:0.79678
# [19100]	train-auc:0.87315	eval-auc:0.79682
# [19200]	train-auc:0.87340	eval-auc:0.79685
# [19300]	train-auc:0.87367	eval-auc:0.79687
# [19400]	train-auc:0.87394	eval-auc:0.79690
# [19500]	train-auc:0.87418	eval-auc:0.79690
# [19600]	train-auc:0.87445	eval-auc:0.79693
# [19700]	train-auc:0.87472	eval-auc:0.79696
# [19800]	train-auc:0.87497	eval-auc:0.79697
# [19900]	train-auc:0.87521	eval-auc:0.79700
# [20000]	train-auc:0.87545	eval-auc:0.79702
# [20100]	train-auc:0.87572	eval-auc:0.79704
# [20200]	train-auc:0.87600	eval-auc:0.79708
# [20300]	train-auc:0.87625	eval-auc:0.79710
# [20400]	train-auc:0.87649	eval-auc:0.79712
# [20500]	train-auc:0.87673	eval-auc:0.79714
# [20600]	train-auc:0.87697	eval-auc:0.79717
# [20700]	train-auc:0.87722	eval-auc:0.79719
# [20800]	train-auc:0.87744	eval-auc:0.79720
# [20900]	train-auc:0.87768	eval-auc:0.79723
# [21000]	train-auc:0.87792	eval-auc:0.79726
# [21100]	train-auc:0.87817	eval-auc:0.79728
# [21200]	train-auc:0.87842	eval-auc:0.79730
# [21300]	train-auc:0.87867	eval-auc:0.79731
# [21400]	train-auc:0.87892	eval-auc:0.79733
# [21500]	train-auc:0.87916	eval-auc:0.79734
# [21600]	train-auc:0.87939	eval-auc:0.79736
# [21700]	train-auc:0.87962	eval-auc:0.79739
# [21800]	train-auc:0.87986	eval-auc:0.79741
# [21900]	train-auc:0.88009	eval-auc:0.79741
# [22000]	train-auc:0.88032	eval-auc:0.79743
# [22100]	train-auc:0.88057	eval-auc:0.79746
# [22200]	train-auc:0.88080	eval-auc:0.79748
# [22300]	train-auc:0.88102	eval-auc:0.79750
# [22400]	train-auc:0.88127	eval-auc:0.79752
# [22500]	train-auc:0.88150	eval-auc:0.79753
# [22600]	train-auc:0.88173	eval-auc:0.79755
# [22700]	train-auc:0.88196	eval-auc:0.79756
# [22800]	train-auc:0.88219	eval-auc:0.79758
# [22900]	train-auc:0.88241	eval-auc:0.79760
# [23000]	train-auc:0.88264	eval-auc:0.79761
# [23100]	train-auc:0.88287	eval-auc:0.79763
# [23200]	train-auc:0.88311	eval-auc:0.79764
# [23300]	train-auc:0.88335	eval-auc:0.79766
# [23400]	train-auc:0.88357	eval-auc:0.79768
# [23500]	train-auc:0.88378	eval-auc:0.79769
# [23600]	train-auc:0.88403	eval-auc:0.79770
# [23700]	train-auc:0.88425	eval-auc:0.79772
# [23800]	train-auc:0.88447	eval-auc:0.79774
# [23900]	train-auc:0.88469	eval-auc:0.79776
# [24000]	train-auc:0.88492	eval-auc:0.79778
# [24100]	train-auc:0.88515	eval-auc:0.79780
# [24200]	train-auc:0.88539	eval-auc:0.79781
# [24300]	train-auc:0.88561	eval-auc:0.79782
# [24400]	train-auc:0.88584	eval-auc:0.79782
# [24500]	train-auc:0.88606	eval-auc:0.79783
# [24600]	train-auc:0.88629	eval-auc:0.79785
# [24700]	train-auc:0.88651	eval-auc:0.79786
# [24800]	train-auc:0.88673	eval-auc:0.79787
# [24900]	train-auc:0.88696	eval-auc:0.79787
# [25000]	train-auc:0.88718	eval-auc:0.79788
# [25100]	train-auc:0.88740	eval-auc:0.79789
# [25200]	train-auc:0.88763	eval-auc:0.79791
# [25300]	train-auc:0.88785	eval-auc:0.79792
# [25400]	train-auc:0.88807	eval-auc:0.79793
# [25500]	train-auc:0.88830	eval-auc:0.79794
# [25600]	train-auc:0.88850	eval-auc:0.79794
# [25700]	train-auc:0.88873	eval-auc:0.79796
# [25800]	train-auc:0.88894	eval-auc:0.79797
# [25900]	train-auc:0.88916	eval-auc:0.79798
# [26000]	train-auc:0.88937	eval-auc:0.79800
# [26100]	train-auc:0.88959	eval-auc:0.79801
# [26200]	train-auc:0.88980	eval-auc:0.79802
# [26300]	train-auc:0.89002	eval-auc:0.79804
# [26400]	train-auc:0.89023	eval-auc:0.79805
# [26500]	train-auc:0.89044	eval-auc:0.79807
# [26600]	train-auc:0.89064	eval-auc:0.79807
# [26700]	train-auc:0.89086	eval-auc:0.79808
# [26800]	train-auc:0.89108	eval-auc:0.79809
# [26900]	train-auc:0.89128	eval-auc:0.79810
# [27000]	train-auc:0.89150	eval-auc:0.79811
# [27100]	train-auc:0.89170	eval-auc:0.79812
# [27200]	train-auc:0.89192	eval-auc:0.79814
# [27300]	train-auc:0.89213	eval-auc:0.79816
# [27400]	train-auc:0.89234	eval-auc:0.79818
# [27500]	train-auc:0.89255	eval-auc:0.79819
# [27600]	train-auc:0.89277	eval-auc:0.79820
# [27700]	train-auc:0.89298	eval-auc:0.79821
# [27800]	train-auc:0.89320	eval-auc:0.79822
# [27900]	train-auc:0.89340	eval-auc:0.79823
# [28000]	train-auc:0.89360	eval-auc:0.79823
# [28100]	train-auc:0.89382	eval-auc:0.79824
# [28200]	train-auc:0.89402	eval-auc:0.79825
# [28300]	train-auc:0.89423	eval-auc:0.79825
# [28400]	train-auc:0.89443	eval-auc:0.79826
# [28500]	train-auc:0.89463	eval-auc:0.79827
# [28600]	train-auc:0.89483	eval-auc:0.79828
# [28700]	train-auc:0.89502	eval-auc:0.79829
# [28800]	train-auc:0.89520	eval-auc:0.79829
# [28900]	train-auc:0.89540	eval-auc:0.79830
# [29000]	train-auc:0.89561	eval-auc:0.79829
# [29100]	train-auc:0.89581	eval-auc:0.79830
# [29200]	train-auc:0.89602	eval-auc:0.79831
# [29300]	train-auc:0.89622	eval-auc:0.79832
# [29400]	train-auc:0.89643	eval-auc:0.79833
# [29500]	train-auc:0.89665	eval-auc:0.79834
# [29600]	train-auc:0.89685	eval-auc:0.79835
# [29700]	train-auc:0.89705	eval-auc:0.79836
# [29800]	train-auc:0.89724	eval-auc:0.79837
# [29900]	train-auc:0.89745	eval-auc:0.79838
# [30000]	train-auc:0.89767	eval-auc:0.79839
# [30100]	train-auc:0.89786	eval-auc:0.79840
# [30200]	train-auc:0.89809	eval-auc:0.79841
# [30300]	train-auc:0.89827	eval-auc:0.79842
# [30400]	train-auc:0.89848	eval-auc:0.79841
# [30500]	train-auc:0.89866	eval-auc:0.79841
# [30600]	train-auc:0.89886	eval-auc:0.79843
# [30700]	train-auc:0.89905	eval-auc:0.79844
# [30800]	train-auc:0.89924	eval-auc:0.79844
# [30900]	train-auc:0.89943	eval-auc:0.79845
# [31000]	train-auc:0.89961	eval-auc:0.79846
# [31100]	train-auc:0.89979	eval-auc:0.79846
# [31200]	train-auc:0.89998	eval-auc:0.79847
# [31300]	train-auc:0.90018	eval-auc:0.79847
# [31400]	train-auc:0.90037	eval-auc:0.79848
# [31500]	train-auc:0.90054	eval-auc:0.79848
# [31600]	train-auc:0.90075	eval-auc:0.79849
# [31700]	train-auc:0.90094	eval-auc:0.79849
# [31800]	train-auc:0.90113	eval-auc:0.79849
# [31900]	train-auc:0.90132	eval-auc:0.79850
# [32000]	train-auc:0.90152	eval-auc:0.79850
# [32100]	train-auc:0.90169	eval-auc:0.79850
# [32200]	train-auc:0.90186	eval-auc:0.79851
# [32300]	train-auc:0.90205	eval-auc:0.79852
# [32400]	train-auc:0.90223	eval-auc:0.79853
# [32500]	train-auc:0.90242	eval-auc:0.79853
# [32600]	train-auc:0.90262	eval-auc:0.79854
# [32700]	train-auc:0.90281	eval-auc:0.79855
# [32800]	train-auc:0.90300	eval-auc:0.79856
# [32900]	train-auc:0.90319	eval-auc:0.79855
# [33000]	train-auc:0.90337	eval-auc:0.79856
# [33100]	train-auc:0.90355	eval-auc:0.79857
# [33200]	train-auc:0.90375	eval-auc:0.79858
# [33300]	train-auc:0.90394	eval-auc:0.79858
# [33400]	train-auc:0.90415	eval-auc:0.79859
# [33500]	train-auc:0.90433	eval-auc:0.79860
# [33600]	train-auc:0.90452	eval-auc:0.79860
# [33700]	train-auc:0.90468	eval-auc:0.79861
# [33800]	train-auc:0.90485	eval-auc:0.79861
# [33900]	train-auc:0.90503	eval-auc:0.79861
# [34000]	train-auc:0.90521	eval-auc:0.79861
# [34100]	train-auc:0.90539	eval-auc:0.79862
# [34200]	train-auc:0.90558	eval-auc:0.79862
# [34300]	train-auc:0.90577	eval-auc:0.79863
# [34400]	train-auc:0.90597	eval-auc:0.79864
# [34500]	train-auc:0.90614	eval-auc:0.79864
# [34600]	train-auc:0.90634	eval-auc:0.79864
# [34700]	train-auc:0.90653	eval-auc:0.79866
# [34800]	train-auc:0.90672	eval-auc:0.79867
# [34900]	train-auc:0.90690	eval-auc:0.79868
# [35000]	train-auc:0.90709	eval-auc:0.79868
# [35100]	train-auc:0.90725	eval-auc:0.79868
# [35200]	train-auc:0.90744	eval-auc:0.79869
# [35300]	train-auc:0.90764	eval-auc:0.79868
# [35400]	train-auc:0.90781	eval-auc:0.79869
# [35500]	train-auc:0.90798	eval-auc:0.79869
# [35600]	train-auc:0.90815	eval-auc:0.79868
# [35700]	train-auc:0.90833	eval-auc:0.79869
# [35800]	train-auc:0.90851	eval-auc:0.79870
# [35900]	train-auc:0.90869	eval-auc:0.79870
# [36000]	train-auc:0.90887	eval-auc:0.79870
# [36100]	train-auc:0.90905	eval-auc:0.79870
# [36200]	train-auc:0.90924	eval-auc:0.79871
# [36300]	train-auc:0.90942	eval-auc:0.79871
# [36400]	train-auc:0.90960	eval-auc:0.79870
# [36500]	train-auc:0.90978	eval-auc:0.79870
# [36600]	train-auc:0.90995	eval-auc:0.79870
# [36700]	train-auc:0.91014	eval-auc:0.79871
# [36800]	train-auc:0.91032	eval-auc:0.79871
# [36900]	train-auc:0.91051	eval-auc:0.79872
# [37000]	train-auc:0.91070	eval-auc:0.79872
# [37100]	train-auc:0.91088	eval-auc:0.79873
# [37200]	train-auc:0.91107	eval-auc:0.79873
# [37300]	train-auc:0.91122	eval-auc:0.79873
# [37400]	train-auc:0.91139	eval-auc:0.79873
# [37500]	train-auc:0.91156	eval-auc:0.79873
# [37600]	train-auc:0.91173	eval-auc:0.79872
# [37700]	train-auc:0.91192	eval-auc:0.79873
# [37800]	train-auc:0.91210	eval-auc:0.79874
# [37900]	train-auc:0.91228	eval-auc:0.79874
# [38000]	train-auc:0.91245	eval-auc:0.79874
# [38100]	train-auc:0.91261	eval-auc:0.79874
# [38200]	train-auc:0.91278	eval-auc:0.79874
# [38300]	train-auc:0.91296	eval-auc:0.79875
# [38400]	train-auc:0.91312	eval-auc:0.79875
# [38500]	train-auc:0.91329	eval-auc:0.79875
# [38600]	train-auc:0.91347	eval-auc:0.79875
# [38700]	train-auc:0.91364	eval-auc:0.79877
# [38800]	train-auc:0.91380	eval-auc:0.79877
# [38900]	train-auc:0.91398	eval-auc:0.79878
# [39000]	train-auc:0.91415	eval-auc:0.79878
# [39100]	train-auc:0.91433	eval-auc:0.79879
# [39200]	train-auc:0.91449	eval-auc:0.79880
# [39300]	train-auc:0.91464	eval-auc:0.79880
# [39400]	train-auc:0.91481	eval-auc:0.79880
# [39500]	train-auc:0.91498	eval-auc:0.79880
# [39600]	train-auc:0.91514	eval-auc:0.79881
# [39700]	train-auc:0.91530	eval-auc:0.79881
# [39800]	train-auc:0.91547	eval-auc:0.79881
# [39900]	train-auc:0.91564	eval-auc:0.79881
# [40000]	train-auc:0.91582	eval-auc:0.79881
# [40100]	train-auc:0.91600	eval-auc:0.79881
# [40200]	train-auc:0.91617	eval-auc:0.79880
# [40300]	train-auc:0.91634	eval-auc:0.79881
# [40400]	train-auc:0.91651	eval-auc:0.79880
# [40500]	train-auc:0.91668	eval-auc:0.79880
# [40600]	train-auc:0.91685	eval-auc:0.79880
# [40700]	train-auc:0.91702	eval-auc:0.79880
# [40800]	train-auc:0.91719	eval-auc:0.79880
# [40900]	train-auc:0.91734	eval-auc:0.79879
# [41000]	train-auc:0.91752	eval-auc:0.79879
# [41100]	train-auc:0.91768	eval-auc:0.79878
# [41200]	train-auc:0.91784	eval-auc:0.79879
# [41300]	train-auc:0.91799	eval-auc:0.79879
# [41400]	train-auc:0.91815	eval-auc:0.79880
# [41468]	train-auc:0.91827	eval-auc:0.79880
# Time elapsed: 2134.1832852363586
# Fold AUC: 0.7988146428230839
# CPU times: user 35min 38s, sys: 4.07 s, total: 35min 42s
# Wall time: 35min 34s

# %%
# %%time
params['eta'] = 0.01


start_time = time()
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].values[train_index], train[good_features].values[test_index]
        y_train, y_val = target[train_index], target[test_index]
        xgtrain = xgb.DMatrix(xgtrain, label = y_train ) 
        xgval = xgb.DMatrix(xgval, label = y_val ) 
        watchlist = [(xgtrain, 'train'), (xgval, 'eval')]
        clf = xgb.train(params, xgtrain, num_boost_round=10000, evals=watchlist, 
                verbose_eval=100, 
                early_stopping_rounds = 200)
        
        #preds = clf.predict(xgtest)
        ypred = clf.predict(xgval, ntree_limit=clf.best_ntree_limit)
        #y_oof[test_index] = ypred
        #preds_total += preds
        #np.save("preds_hist_"+str(i), preds)
        #p.save("oof_preds_hist_"+str(i), ypred)
        print('Time elapsed:', time()-start_time)
        #clf.save_model('xgb_gpu_hist_1812_2_fold_'+str(i)+'.model')
        del clf
        gc.collect()
        i +=1
        print('Fold AUC:', roc_auc_score(y_val, ypred))
        
        break
# Out:
# 1
# [0]	train-auc:0.75684	eval-auc:0.74114
# [100]	train-auc:0.78491	eval-auc:0.76299
# [200]	train-auc:0.79218	eval-auc:0.76740
# [300]	train-auc:0.80006	eval-auc:0.77176
# [400]	train-auc:0.80895	eval-auc:0.77676
# [500]	train-auc:0.81755	eval-auc:0.78116
# [600]	train-auc:0.82484	eval-auc:0.78477
# [700]	train-auc:0.83085	eval-auc:0.78738
# [800]	train-auc:0.83591	eval-auc:0.78906
# [900]	train-auc:0.84048	eval-auc:0.79052
# [1000]	train-auc:0.84436	eval-auc:0.79169
# [1100]	train-auc:0.84800	eval-auc:0.79270
# [1200]	train-auc:0.85152	eval-auc:0.79344
# [1300]	train-auc:0.85490	eval-auc:0.79407
# [1400]	train-auc:0.85808	eval-auc:0.79463
# [1500]	train-auc:0.86112	eval-auc:0.79512
# [1600]	train-auc:0.86395	eval-auc:0.79556
# [1700]	train-auc:0.86694	eval-auc:0.79590
# [1800]	train-auc:0.86973	eval-auc:0.79619
# [1900]	train-auc:0.87237	eval-auc:0.79647
# [2000]	train-auc:0.87486	eval-auc:0.79671
# [2100]	train-auc:0.87728	eval-auc:0.79698
# [2200]	train-auc:0.87959	eval-auc:0.79720
# [2300]	train-auc:0.88180	eval-auc:0.79735
# [2400]	train-auc:0.88408	eval-auc:0.79746
# [2500]	train-auc:0.88619	eval-auc:0.79768
# [2600]	train-auc:0.88816	eval-auc:0.79783
# [2700]	train-auc:0.89022	eval-auc:0.79804
# [2800]	train-auc:0.89241	eval-auc:0.79818
# [2900]	train-auc:0.89463	eval-auc:0.79820
# [3000]	train-auc:0.89667	eval-auc:0.79832
# [3100]	train-auc:0.89853	eval-auc:0.79833
# [3200]	train-auc:0.90051	eval-auc:0.79836
# [3300]	train-auc:0.90249	eval-auc:0.79843
# [3400]	train-auc:0.90439	eval-auc:0.79844
# [3500]	train-auc:0.90627	eval-auc:0.79846
# [3600]	train-auc:0.90803	eval-auc:0.79848
# [3700]	train-auc:0.90977	eval-auc:0.79852
# [3800]	train-auc:0.91165	eval-auc:0.79854
# [3900]	train-auc:0.91331	eval-auc:0.79852
# [3942]	train-auc:0.91397	eval-auc:0.79850
# Time elapsed: 212.70046758651733
# Fold AUC: 0.7985728088412014
# CPU times: user 3min 38s, sys: 3.31 s, total: 3min 41s
# Wall time: 3min 32s

# %%
# %%time
params['eta'] = 0.03


start_time = time()
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].values[train_index], train[good_features].values[test_index]
        y_train, y_val = target[train_index], target[test_index]
        xgtrain = xgb.DMatrix(xgtrain, label = y_train ) 
        xgval = xgb.DMatrix(xgval, label = y_val ) 
        watchlist = [(xgtrain, 'train'), (xgval, 'eval')]
        clf = xgb.train(params, xgtrain, num_boost_round=10000, evals=watchlist, 
                verbose_eval=100, 
                early_stopping_rounds = 100)
        
        #preds = clf.predict(xgtest)
        ypred = clf.predict(xgval, ntree_limit=clf.best_ntree_limit)
        #y_oof[test_index] = ypred
        #preds_total += preds
        #np.save("preds_hist_"+str(i), preds)
        #p.save("oof_preds_hist_"+str(i), ypred)
        print('Time elapsed:', time()-start_time)
        #clf.save_model('xgb_gpu_hist_1812_2_fold_'+str(i)+'.model')
        del clf
        gc.collect()
        i +=1
        print('Fold AUC:', roc_auc_score(y_val, ypred))
        
        break
# Out:
# 1
# [0]	train-auc:0.75684	eval-auc:0.74114
# [100]	train-auc:0.79963	eval-auc:0.77163
# [200]	train-auc:0.82433	eval-auc:0.78354
# [300]	train-auc:0.83969	eval-auc:0.78941
# [400]	train-auc:0.85126	eval-auc:0.79219
# [500]	train-auc:0.86071	eval-auc:0.79379
# [600]	train-auc:0.86889	eval-auc:0.79458
# [700]	train-auc:0.87669	eval-auc:0.79524
# [800]	train-auc:0.88416	eval-auc:0.79571
# [900]	train-auc:0.89045	eval-auc:0.79580
# [979]	train-auc:0.89508	eval-auc:0.79579
# Time elapsed: 60.63681197166443
# Fold AUC: 0.7958909365808279
# CPU times: user 1min 6s, sys: 3.36 s, total: 1min 9s
# Wall time: 1min

# %%
train[good_features].loc[[1,5,99]]
# Out:
#     AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 1                         0.0                         0.0
# 5                         0.0                         0.0
# 99                        NaN                         NaN
#
#     AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 1                         0.0                         0.0
# 5                         0.0                         0.0
# 99                        NaN                         NaN
#
#     AMT_REQ_CREDIT_BUREAU_YEAR  APARTMENTS_AVG  APARTMENTS_MEDI  \
# 1                          0.0          0.0959           0.0968
# 5                          1.0             NaN              NaN
# 99                         NaN          0.1361           0.1374
#
#     APARTMENTS_MODE  BASEMENTAREA_AVG  BASEMENTAREA_MEDI  ...  \
# 1            0.0924            0.0529             0.0529  ...
# 5               NaN               NaN                NaN  ...
# 99           0.0777            0.0761             0.0761  ...
#
#     total_credit_None  debt_credit_ratio_None  AGE_INT  ORGANIZATION_TYPE_cnt  \
# 1           1017400.5                0.000000       45                  10180
# 5            468445.5                0.512454       46                  19390
# 99                NaN                     NaN       61                  64648
#
#     region_id  prev_app_decision_days_max  \
# 1    0.003541                      -746.0
# 5    0.035792                       -82.0
# 99   0.026392                     -1105.0
#
#     prev_app_days_approved_decision_max  neighbors_target_mean_500  \
# 1                                -746.0                   0.040080
# 5                                -370.0                   0.032064
# 99                              -1105.0                   0.046092
#
#     neighbors_500_credit_downpayment_median  \
# 1                                -165012.75
# 5                                 -49896.00
# 99                                -66825.00
#
#     neighbors_500_DAYS_CREDIT_mean_median
# 1                                     NaN
# 5                                     NaN
# 99                                    NaN
#
# [3 rows x 1828 columns]

# %%
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].loc[train_index], train[good_features].loc[test_index]
        y_train, y_val = target[train_index], target[test_index]
        
        break
# Out:
# 1

# %%
xgtrain.head()
# Out:
#    AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 0                        0.0                         0.0
# 3                        NaN                         NaN
# 4                        0.0                         0.0
# 5                        0.0                         0.0
# 6                        0.0                         0.0
#
#    AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 0                        0.0                         0.0
# 3                        NaN                         NaN
# 4                        0.0                         0.0
# 5                        0.0                         0.0
# 6                        1.0                         0.0
#
#    AMT_REQ_CREDIT_BUREAU_YEAR  APARTMENTS_AVG  APARTMENTS_MEDI  \
# 0                         1.0          0.0247            0.025
# 3                         NaN             NaN              NaN
# 4                         0.0             NaN              NaN
# 5                         1.0             NaN              NaN
# 6                         2.0             NaN              NaN
#
#    APARTMENTS_MODE  BASEMENTAREA_AVG  BASEMENTAREA_MEDI  ...  \
# 0           0.0252            0.0369             0.0369  ...
# 3              NaN               NaN                NaN  ...
# 4              NaN               NaN                NaN  ...
# 5              NaN               NaN                NaN  ...
# 6              NaN               NaN                NaN  ...
#
#    total_credit_None  debt_credit_ratio_None  AGE_INT  ORGANIZATION_TYPE_cnt  \
# 0         865055.565                0.284122       25                  78832
# 3                NaN                     NaN       52                  78832
# 4         146250.000                0.000000       54                     97
# 5         468445.500                0.512454       46                  19390
# 6        4800811.500                0.224410       37                  78832
#
#    region_id  prev_app_decision_days_max  prev_app_days_approved_decision_max  \
# 0   0.018801                      -606.0                               -606.0
# 3   0.008019                      -181.0                               -181.0
# 4   0.028663                      -374.0                               -374.0
# 5   0.035792                       -82.0                               -370.0
# 6   0.035792                       -74.0                                -74.0
#
#    neighbors_target_mean_500  neighbors_500_credit_downpayment_median  \
# 0                   0.278557                                -58236.75
# 3                   0.034068                                -18000.00
# 4                   0.072144                                -78588.00
# 5                   0.032064                                -49896.00
# 6                   0.010020                               -163469.25
#
#    neighbors_500_DAYS_CREDIT_mean_median
# 0                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
#
# [5 rows x 1828 columns]

# %%
xgtrain['target'] = y_train
xgval['target'] = y_val

# %%
xgtrain.to_csv('../input/xgtrain.csv', index=False)
xgval.to_csv('../input/xgval.csv', index=False)
