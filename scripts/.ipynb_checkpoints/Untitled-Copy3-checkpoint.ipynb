# %%
import numpy as np
import pandas as pd
import gc
import time

from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
from tqdm import tqdm

import warnings
from time import time
import xgboost as xgb
xgb.__version__
# Out:
# '1.3.3'

# %%
# %%time
train = pd.read_csv('../input/train_1830.csv')
# Out:
# CPU times: user 43.7 s, sys: 3.97 s, total: 47.7 s
# Wall time: 47.7 s

# %%
application_train = pd.read_csv('../input/application_train.csv')
target = application_train.TARGET.values

# %%
good_features = train.columns[2:]

# %%
params = {
    'objective' : "binary:logistic",
    'booster' : "gbtree",
    'eval_metric' : "auc",
    'nthread' : -1,
    'eta' : 0.0005,
    'max_depth' : 6,
    'min_child_weight' : 22,
    'gamma' :0,
    'subsample' : 0.7,
    'colsample_bytree' : 0.7,
    'colsample_bylevel' : 0.675,
    'alpha' : 0.00,
    'lambda' : 0.00,
    'tree_method' : 'gpu_hist',
    'predictor': 'gpu_predictor',
    #'scale_pos_weights' : 1,
    #'nrounds' : 100000,
    #'verbose_eval': 1250,
    'seed' : 19947
}

# %%
# %%time
start_time = time()
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].values[train_index], train[good_features].values[test_index]
        y_train, y_val = target[train_index], target[test_index]
        xgtrain = xgb.DMatrix(xgtrain, label = y_train ) 
        xgval = xgb.DMatrix(xgval, label = y_val ) 
        watchlist = [(xgtrain, 'train'), (xgval, 'eval')]
        clf = xgb.train(params, xgtrain, num_boost_round=200000, evals=watchlist, 
                verbose_eval=200, 
                early_stopping_rounds = 3000)
        
        #preds = clf.predict(xgtest)
        ypred = clf.predict(xgval, ntree_limit=clf.best_ntree_limit)
        #y_oof[test_index] = ypred
        #preds_total += preds
        #np.save("preds_hist_"+str(i), preds)
        #p.save("oof_preds_hist_"+str(i), ypred)
        print('Time elapsed:', time()-start_time)
        #clf.save_model('xgb_gpu_hist_1812_2_fold_'+str(i)+'.model')
        del clf
        gc.collect()
        i +=1
        print('Fold AUC:', roc_auc_score(y_val, ypred))
        
        break
# Out:
# 1
# [0]	train-auc:0.75684	eval-auc:0.74116
# [200]	train-auc:0.77892	eval-auc:0.75948
# [400]	train-auc:0.77990	eval-auc:0.76010
# [600]	train-auc:0.78079	eval-auc:0.76067
# [800]	train-auc:0.78158	eval-auc:0.76111
# [1000]	train-auc:0.78227	eval-auc:0.76158
# [1200]	train-auc:0.78290	eval-auc:0.76200
# [1400]	train-auc:0.78353	eval-auc:0.76240
# [1600]	train-auc:0.78413	eval-auc:0.76278
# [1800]	train-auc:0.78473	eval-auc:0.76315
# [2000]	train-auc:0.78538	eval-auc:0.76352
# [2200]	train-auc:0.78602	eval-auc:0.76392
# [2400]	train-auc:0.78669	eval-auc:0.76433
# [2600]	train-auc:0.78738	eval-auc:0.76480
# [2800]	train-auc:0.78809	eval-auc:0.76523
# [3000]	train-auc:0.78879	eval-auc:0.76565
# [3200]	train-auc:0.78949	eval-auc:0.76607
# [3400]	train-auc:0.79022	eval-auc:0.76651
# [3600]	train-auc:0.79096	eval-auc:0.76694
# [3800]	train-auc:0.79168	eval-auc:0.76733
# [4000]	train-auc:0.79240	eval-auc:0.76772
# [4200]	train-auc:0.79314	eval-auc:0.76814
# [4400]	train-auc:0.79389	eval-auc:0.76857
# [4600]	train-auc:0.79468	eval-auc:0.76902
# [4800]	train-auc:0.79544	eval-auc:0.76943
# [5000]	train-auc:0.79625	eval-auc:0.76991
# [5200]	train-auc:0.79704	eval-auc:0.77037
# [5400]	train-auc:0.79788	eval-auc:0.77082
# [5600]	train-auc:0.79867	eval-auc:0.77124
# [5800]	train-auc:0.79951	eval-auc:0.77172
# [6000]	train-auc:0.80037	eval-auc:0.77222
# [6200]	train-auc:0.80124	eval-auc:0.77272
# [6400]	train-auc:0.80212	eval-auc:0.77323
# [6600]	train-auc:0.80298	eval-auc:0.77373
# [6800]	train-auc:0.80384	eval-auc:0.77422
# [7000]	train-auc:0.80475	eval-auc:0.77473
# [7200]	train-auc:0.80563	eval-auc:0.77521
# [7400]	train-auc:0.80652	eval-auc:0.77567
# [7600]	train-auc:0.80739	eval-auc:0.77615
# [7800]	train-auc:0.80825	eval-auc:0.77660
# [8000]	train-auc:0.80911	eval-auc:0.77706
# [8200]	train-auc:0.80994	eval-auc:0.77749
# [8400]	train-auc:0.81080	eval-auc:0.77793
# [8600]	train-auc:0.81165	eval-auc:0.77838
# [8800]	train-auc:0.81251	eval-auc:0.77883
# [9000]	train-auc:0.81336	eval-auc:0.77927
# [9200]	train-auc:0.81420	eval-auc:0.77972
# [9400]	train-auc:0.81502	eval-auc:0.78012
# [9600]	train-auc:0.81586	eval-auc:0.78054
# [9800]	train-auc:0.81668	eval-auc:0.78096
# [10000]	train-auc:0.81753	eval-auc:0.78138
# [10200]	train-auc:0.81836	eval-auc:0.78181
# [10400]	train-auc:0.81916	eval-auc:0.78221
# [10600]	train-auc:0.81996	eval-auc:0.78260
# [10800]	train-auc:0.82075	eval-auc:0.78298
# [11000]	train-auc:0.82150	eval-auc:0.78334
# [11200]	train-auc:0.82222	eval-auc:0.78370
# [11400]	train-auc:0.82296	eval-auc:0.78403
# [11600]	train-auc:0.82368	eval-auc:0.78435
# [11800]	train-auc:0.82438	eval-auc:0.78467
# [12000]	train-auc:0.82505	eval-auc:0.78497
# [12200]	train-auc:0.82572	eval-auc:0.78528
# [12400]	train-auc:0.82636	eval-auc:0.78555
# [12600]	train-auc:0.82700	eval-auc:0.78583
# [12800]	train-auc:0.82761	eval-auc:0.78610
# [13000]	train-auc:0.82823	eval-auc:0.78636
# [13200]	train-auc:0.82881	eval-auc:0.78662
# [13400]	train-auc:0.82940	eval-auc:0.78687
# [13600]	train-auc:0.82998	eval-auc:0.78711
# [13800]	train-auc:0.83056	eval-auc:0.78734
# [14000]	train-auc:0.83111	eval-auc:0.78756
# [14200]	train-auc:0.83167	eval-auc:0.78778
# [14400]	train-auc:0.83220	eval-auc:0.78798
# [14600]	train-auc:0.83273	eval-auc:0.78819
# [14800]	train-auc:0.83325	eval-auc:0.78839
# [15000]	train-auc:0.83377	eval-auc:0.78859
# [15200]	train-auc:0.83427	eval-auc:0.78877
# [15400]	train-auc:0.83476	eval-auc:0.78896
# [15600]	train-auc:0.83526	eval-auc:0.78913
# [15800]	train-auc:0.83573	eval-auc:0.78930
# [16000]	train-auc:0.83621	eval-auc:0.78947
# [16200]	train-auc:0.83667	eval-auc:0.78963
# [16400]	train-auc:0.83714	eval-auc:0.78979
# [16600]	train-auc:0.83760	eval-auc:0.78993
# [16800]	train-auc:0.83805	eval-auc:0.79008
# [17000]	train-auc:0.83851	eval-auc:0.79023
# [17200]	train-auc:0.83893	eval-auc:0.79036
# [17400]	train-auc:0.83938	eval-auc:0.79049
# [17600]	train-auc:0.83982	eval-auc:0.79062
# [17800]	train-auc:0.84028	eval-auc:0.79076
# [18000]	train-auc:0.84072	eval-auc:0.79089
# [18200]	train-auc:0.84115	eval-auc:0.79101
# [18400]	train-auc:0.84155	eval-auc:0.79113
# [18600]	train-auc:0.84198	eval-auc:0.79126
# [18800]	train-auc:0.84241	eval-auc:0.79138
# [19000]	train-auc:0.84282	eval-auc:0.79149
# [19200]	train-auc:0.84323	eval-auc:0.79161
# [19400]	train-auc:0.84363	eval-auc:0.79171
# [19600]	train-auc:0.84404	eval-auc:0.79181
# [19800]	train-auc:0.84444	eval-auc:0.79191
# [20000]	train-auc:0.84483	eval-auc:0.79201
# [20200]	train-auc:0.84522	eval-auc:0.79212
# [20400]	train-auc:0.84561	eval-auc:0.79222
# [20600]	train-auc:0.84599	eval-auc:0.79231
# [20800]	train-auc:0.84638	eval-auc:0.79242
# [21000]	train-auc:0.84676	eval-auc:0.79252
# [21200]	train-auc:0.84713	eval-auc:0.79261
# [21400]	train-auc:0.84750	eval-auc:0.79269
# [21600]	train-auc:0.84786	eval-auc:0.79278
# [21800]	train-auc:0.84822	eval-auc:0.79286
# [22000]	train-auc:0.84860	eval-auc:0.79295
# [22200]	train-auc:0.84898	eval-auc:0.79302
# [22400]	train-auc:0.84933	eval-auc:0.79310
# [22600]	train-auc:0.84969	eval-auc:0.79318
# [22800]	train-auc:0.85005	eval-auc:0.79326
# [23000]	train-auc:0.85040	eval-auc:0.79333
# [23200]	train-auc:0.85074	eval-auc:0.79340
# [23400]	train-auc:0.85109	eval-auc:0.79347
# [23600]	train-auc:0.85144	eval-auc:0.79355
# [23800]	train-auc:0.85179	eval-auc:0.79362
# [24000]	train-auc:0.85213	eval-auc:0.79369
# [24200]	train-auc:0.85247	eval-auc:0.79376
# [24400]	train-auc:0.85283	eval-auc:0.79382
# [24600]	train-auc:0.85317	eval-auc:0.79389
# [24800]	train-auc:0.85350	eval-auc:0.79396
# [25000]	train-auc:0.85385	eval-auc:0.79403
# [25200]	train-auc:0.85418	eval-auc:0.79409
# [25400]	train-auc:0.85452	eval-auc:0.79416
# [25600]	train-auc:0.85484	eval-auc:0.79422
# [25800]	train-auc:0.85517	eval-auc:0.79429
# [26000]	train-auc:0.85550	eval-auc:0.79434
# [26200]	train-auc:0.85583	eval-auc:0.79440
# [26400]	train-auc:0.85615	eval-auc:0.79446
# [26600]	train-auc:0.85647	eval-auc:0.79452
# [26800]	train-auc:0.85681	eval-auc:0.79458
# [27000]	train-auc:0.85712	eval-auc:0.79464
# [27200]	train-auc:0.85744	eval-auc:0.79470
# [27400]	train-auc:0.85776	eval-auc:0.79475
# [27600]	train-auc:0.85808	eval-auc:0.79481
# [27800]	train-auc:0.85840	eval-auc:0.79486
# [28000]	train-auc:0.85871	eval-auc:0.79492
# [28200]	train-auc:0.85902	eval-auc:0.79497
# [28400]	train-auc:0.85933	eval-auc:0.79502
# [28600]	train-auc:0.85963	eval-auc:0.79507
# [28800]	train-auc:0.85994	eval-auc:0.79511
# [29000]	train-auc:0.86025	eval-auc:0.79517
# [29200]	train-auc:0.86055	eval-auc:0.79522
# [29400]	train-auc:0.86086	eval-auc:0.79527
# [29600]	train-auc:0.86115	eval-auc:0.79532
# [29800]	train-auc:0.86144	eval-auc:0.79537
# [30000]	train-auc:0.86175	eval-auc:0.79542
# [30200]	train-auc:0.86207	eval-auc:0.79548
# [30400]	train-auc:0.86237	eval-auc:0.79553
# [30600]	train-auc:0.86267	eval-auc:0.79557
# [30800]	train-auc:0.86296	eval-auc:0.79561
# [31000]	train-auc:0.86325	eval-auc:0.79566
# [31200]	train-auc:0.86355	eval-auc:0.79570
# [31400]	train-auc:0.86385	eval-auc:0.79574
# [31600]	train-auc:0.86412	eval-auc:0.79578
# [31800]	train-auc:0.86442	eval-auc:0.79581
# [32000]	train-auc:0.86470	eval-auc:0.79585
# [32200]	train-auc:0.86497	eval-auc:0.79588
# [32400]	train-auc:0.86526	eval-auc:0.79592
# [32600]	train-auc:0.86555	eval-auc:0.79596
# [32800]	train-auc:0.86583	eval-auc:0.79600
# [33000]	train-auc:0.86611	eval-auc:0.79603
# [33200]	train-auc:0.86638	eval-auc:0.79607
# [33400]	train-auc:0.86666	eval-auc:0.79610
# [33600]	train-auc:0.86694	eval-auc:0.79614
# [33800]	train-auc:0.86721	eval-auc:0.79618
# [34000]	train-auc:0.86749	eval-auc:0.79621
# [34200]	train-auc:0.86777	eval-auc:0.79624
# [34400]	train-auc:0.86805	eval-auc:0.79627
# [34600]	train-auc:0.86834	eval-auc:0.79631
# [34800]	train-auc:0.86862	eval-auc:0.79635
# [35000]	train-auc:0.86889	eval-auc:0.79638
# [35200]	train-auc:0.86918	eval-auc:0.79641
# [35400]	train-auc:0.86945	eval-auc:0.79645
# [35600]	train-auc:0.86970	eval-auc:0.79647
# [35800]	train-auc:0.86997	eval-auc:0.79651
# [36000]	train-auc:0.87023	eval-auc:0.79654
# [36200]	train-auc:0.87050	eval-auc:0.79658
# [36400]	train-auc:0.87077	eval-auc:0.79660
# [36600]	train-auc:0.87104	eval-auc:0.79663
# [36800]	train-auc:0.87131	eval-auc:0.79666
# [37000]	train-auc:0.87158	eval-auc:0.79668
# [37200]	train-auc:0.87185	eval-auc:0.79672
# [37400]	train-auc:0.87211	eval-auc:0.79675
# [37600]	train-auc:0.87237	eval-auc:0.79677
# [37800]	train-auc:0.87264	eval-auc:0.79680
# [38000]	train-auc:0.87290	eval-auc:0.79683
# [38200]	train-auc:0.87316	eval-auc:0.79685
# [38400]	train-auc:0.87342	eval-auc:0.79687
# [38600]	train-auc:0.87368	eval-auc:0.79689
# [38800]	train-auc:0.87394	eval-auc:0.79692
# [39000]	train-auc:0.87418	eval-auc:0.79694
# [39200]	train-auc:0.87443	eval-auc:0.79697
# [39400]	train-auc:0.87468	eval-auc:0.79700
# [39600]	train-auc:0.87492	eval-auc:0.79702
# [39800]	train-auc:0.87517	eval-auc:0.79704
# [40000]	train-auc:0.87542	eval-auc:0.79706
# [40200]	train-auc:0.87568	eval-auc:0.79708
# [40400]	train-auc:0.87593	eval-auc:0.79710
# [40600]	train-auc:0.87618	eval-auc:0.79712
# [40800]	train-auc:0.87642	eval-auc:0.79714
# [41000]	train-auc:0.87666	eval-auc:0.79716
# [41200]	train-auc:0.87690	eval-auc:0.79718
# [41400]	train-auc:0.87714	eval-auc:0.79720
# [41600]	train-auc:0.87739	eval-auc:0.79722
# [41800]	train-auc:0.87764	eval-auc:0.79724
# [42000]	train-auc:0.87789	eval-auc:0.79726
# [42200]	train-auc:0.87812	eval-auc:0.79727
# [42400]	train-auc:0.87836	eval-auc:0.79729
# [42600]	train-auc:0.87860	eval-auc:0.79731
# [42800]	train-auc:0.87885	eval-auc:0.79733
# [43000]	train-auc:0.87909	eval-auc:0.79735
# [43200]	train-auc:0.87933	eval-auc:0.79736
# [43400]	train-auc:0.87957	eval-auc:0.79738
# [43600]	train-auc:0.87981	eval-auc:0.79739
# [43800]	train-auc:0.88004	eval-auc:0.79741
# [44000]	train-auc:0.88028	eval-auc:0.79743
# [44200]	train-auc:0.88052	eval-auc:0.79745
# [44400]	train-auc:0.88074	eval-auc:0.79747
# [44600]	train-auc:0.88098	eval-auc:0.79749
# [44800]	train-auc:0.88122	eval-auc:0.79751
# [45000]	train-auc:0.88144	eval-auc:0.79752
# [45200]	train-auc:0.88167	eval-auc:0.79755
# [45400]	train-auc:0.88191	eval-auc:0.79756
# [45600]	train-auc:0.88215	eval-auc:0.79758
# [45800]	train-auc:0.88239	eval-auc:0.79760
# [46000]	train-auc:0.88262	eval-auc:0.79762
# [46200]	train-auc:0.88285	eval-auc:0.79763
# [46400]	train-auc:0.88308	eval-auc:0.79766
# [46600]	train-auc:0.88331	eval-auc:0.79768
# [46800]	train-auc:0.88353	eval-auc:0.79769
# [47000]	train-auc:0.88374	eval-auc:0.79770
# [47200]	train-auc:0.88397	eval-auc:0.79772
# [47400]	train-auc:0.88420	eval-auc:0.79773
# [47600]	train-auc:0.88441	eval-auc:0.79774
# [47800]	train-auc:0.88465	eval-auc:0.79776
# [48000]	train-auc:0.88490	eval-auc:0.79778
# [48200]	train-auc:0.88514	eval-auc:0.79780
# [48400]	train-auc:0.88536	eval-auc:0.79781
# [48600]	train-auc:0.88558	eval-auc:0.79783
# [48800]	train-auc:0.88580	eval-auc:0.79784
# [49000]	train-auc:0.88603	eval-auc:0.79785
# [49200]	train-auc:0.88624	eval-auc:0.79787
# [49400]	train-auc:0.88647	eval-auc:0.79788
# [49600]	train-auc:0.88668	eval-auc:0.79790
# [49800]	train-auc:0.88692	eval-auc:0.79792
# [50000]	train-auc:0.88714	eval-auc:0.79794
# [50200]	train-auc:0.88736	eval-auc:0.79795
# [50400]	train-auc:0.88757	eval-auc:0.79796
# [50600]	train-auc:0.88780	eval-auc:0.79797
# [50800]	train-auc:0.88801	eval-auc:0.79799
# [51000]	train-auc:0.88824	eval-auc:0.79800
# [51200]	train-auc:0.88845	eval-auc:0.79802
# [51400]	train-auc:0.88866	eval-auc:0.79803
# [51600]	train-auc:0.88887	eval-auc:0.79804
# [51800]	train-auc:0.88909	eval-auc:0.79805
# [52000]	train-auc:0.88931	eval-auc:0.79806
# [52200]	train-auc:0.88953	eval-auc:0.79807
# [52400]	train-auc:0.88975	eval-auc:0.79809
# [52600]	train-auc:0.88997	eval-auc:0.79810
# [52800]	train-auc:0.89019	eval-auc:0.79811
# [53000]	train-auc:0.89039	eval-auc:0.79813
# [53200]	train-auc:0.89060	eval-auc:0.79813
# [53400]	train-auc:0.89082	eval-auc:0.79814
# [53600]	train-auc:0.89103	eval-auc:0.79815
# [53800]	train-auc:0.89124	eval-auc:0.79816
# [54000]	train-auc:0.89145	eval-auc:0.79818
# [54200]	train-auc:0.89165	eval-auc:0.79819
# [54400]	train-auc:0.89187	eval-auc:0.79820
# [54600]	train-auc:0.89209	eval-auc:0.79821
# [54800]	train-auc:0.89229	eval-auc:0.79822
# [55000]	train-auc:0.89251	eval-auc:0.79824
# [55200]	train-auc:0.89272	eval-auc:0.79825
# [55400]	train-auc:0.89293	eval-auc:0.79825
# [55600]	train-auc:0.89315	eval-auc:0.79826
# [55800]	train-auc:0.89336	eval-auc:0.79827
# [56000]	train-auc:0.89358	eval-auc:0.79829
# [56200]	train-auc:0.89379	eval-auc:0.79830
# [56400]	train-auc:0.89400	eval-auc:0.79831
# [56600]	train-auc:0.89419	eval-auc:0.79832
# [56800]	train-auc:0.89439	eval-auc:0.79833
# [57000]	train-auc:0.89459	eval-auc:0.79834
# [57200]	train-auc:0.89479	eval-auc:0.79835
# [57400]	train-auc:0.89500	eval-auc:0.79836
# [57600]	train-auc:0.89520	eval-auc:0.79836
# [57800]	train-auc:0.89541	eval-auc:0.79837
# [58000]	train-auc:0.89562	eval-auc:0.79837
# [58200]	train-auc:0.89582	eval-auc:0.79839
# [58400]	train-auc:0.89602	eval-auc:0.79840
# [58600]	train-auc:0.89621	eval-auc:0.79840
# [58800]	train-auc:0.89640	eval-auc:0.79841
# [59000]	train-auc:0.89659	eval-auc:0.79842
# [59200]	train-auc:0.89680	eval-auc:0.79843
# [59400]	train-auc:0.89700	eval-auc:0.79843
# [59600]	train-auc:0.89721	eval-auc:0.79844
# [59800]	train-auc:0.89741	eval-auc:0.79844
# [60000]	train-auc:0.89762	eval-auc:0.79845
# [60200]	train-auc:0.89782	eval-auc:0.79846
# [60400]	train-auc:0.89802	eval-auc:0.79846
# [60600]	train-auc:0.89821	eval-auc:0.79847
# [60800]	train-auc:0.89840	eval-auc:0.79848
# [61000]	train-auc:0.89860	eval-auc:0.79849
# [61200]	train-auc:0.89879	eval-auc:0.79849
# [61400]	train-auc:0.89900	eval-auc:0.79849
# [61600]	train-auc:0.89921	eval-auc:0.79849
# [61800]	train-auc:0.89940	eval-auc:0.79850
# [62000]	train-auc:0.89959	eval-auc:0.79850
# [62200]	train-auc:0.89978	eval-auc:0.79851
# [62400]	train-auc:0.89997	eval-auc:0.79852
# [62600]	train-auc:0.90016	eval-auc:0.79853
# [62800]	train-auc:0.90035	eval-auc:0.79853
# [63000]	train-auc:0.90053	eval-auc:0.79853
# [63200]	train-auc:0.90073	eval-auc:0.79854
# [63400]	train-auc:0.90092	eval-auc:0.79855
# [63600]	train-auc:0.90111	eval-auc:0.79855
# [63800]	train-auc:0.90130	eval-auc:0.79855
# [64000]	train-auc:0.90149	eval-auc:0.79856
# [64200]	train-auc:0.90167	eval-auc:0.79856
# [64400]	train-auc:0.90186	eval-auc:0.79858
# [64600]	train-auc:0.90204	eval-auc:0.79857
# [64800]	train-auc:0.90223	eval-auc:0.79858
# [65000]	train-auc:0.90242	eval-auc:0.79859
# [65200]	train-auc:0.90261	eval-auc:0.79859
# [65400]	train-auc:0.90279	eval-auc:0.79860
# [65600]	train-auc:0.90298	eval-auc:0.79861
# [65800]	train-auc:0.90316	eval-auc:0.79861
# [66000]	train-auc:0.90335	eval-auc:0.79862
# [66200]	train-auc:0.90354	eval-auc:0.79862
# [66400]	train-auc:0.90374	eval-auc:0.79863
# [66600]	train-auc:0.90392	eval-auc:0.79863
# [66800]	train-auc:0.90411	eval-auc:0.79863
# [67000]	train-auc:0.90429	eval-auc:0.79864
# [67200]	train-auc:0.90449	eval-auc:0.79865
# [67400]	train-auc:0.90468	eval-auc:0.79865
# [67600]	train-auc:0.90486	eval-auc:0.79866
# [67800]	train-auc:0.90505	eval-auc:0.79866
# [68000]	train-auc:0.90522	eval-auc:0.79867
# [68200]	train-auc:0.90541	eval-auc:0.79867
# [68400]	train-auc:0.90560	eval-auc:0.79868
# [68600]	train-auc:0.90578	eval-auc:0.79868
# [68800]	train-auc:0.90597	eval-auc:0.79868
# [69000]	train-auc:0.90616	eval-auc:0.79868
# [69200]	train-auc:0.90634	eval-auc:0.79868
# [69400]	train-auc:0.90652	eval-auc:0.79870
# [69600]	train-auc:0.90670	eval-auc:0.79870
# [69800]	train-auc:0.90690	eval-auc:0.79870
# [70000]	train-auc:0.90707	eval-auc:0.79870
# [70200]	train-auc:0.90724	eval-auc:0.79869
# [70400]	train-auc:0.90742	eval-auc:0.79869
# [70600]	train-auc:0.90760	eval-auc:0.79869
# [70800]	train-auc:0.90778	eval-auc:0.79870
# [71000]	train-auc:0.90797	eval-auc:0.79870
# [71200]	train-auc:0.90815	eval-auc:0.79870
# [71400]	train-auc:0.90832	eval-auc:0.79870
# [71600]	train-auc:0.90851	eval-auc:0.79871
# [71800]	train-auc:0.90869	eval-auc:0.79871
# [72000]	train-auc:0.90889	eval-auc:0.79871
# [72200]	train-auc:0.90906	eval-auc:0.79871
# [72400]	train-auc:0.90925	eval-auc:0.79872
# [72600]	train-auc:0.90942	eval-auc:0.79872
# [72800]	train-auc:0.90961	eval-auc:0.79873
# [73000]	train-auc:0.90978	eval-auc:0.79873
# [73200]	train-auc:0.90995	eval-auc:0.79873
# [73400]	train-auc:0.91014	eval-auc:0.79873
# [73600]	train-auc:0.91031	eval-auc:0.79874
# [73800]	train-auc:0.91049	eval-auc:0.79875
# [74000]	train-auc:0.91067	eval-auc:0.79875
# [74200]	train-auc:0.91084	eval-auc:0.79876
# [74400]	train-auc:0.91102	eval-auc:0.79876
# [74600]	train-auc:0.91120	eval-auc:0.79876
# [74800]	train-auc:0.91137	eval-auc:0.79876
# [75000]	train-auc:0.91155	eval-auc:0.79876
# [75200]	train-auc:0.91172	eval-auc:0.79876
# [75400]	train-auc:0.91188	eval-auc:0.79876
# [75600]	train-auc:0.91205	eval-auc:0.79876
# [75800]	train-auc:0.91223	eval-auc:0.79877
# [76000]	train-auc:0.91240	eval-auc:0.79876
# [76200]	train-auc:0.91259	eval-auc:0.79877
# [76400]	train-auc:0.91276	eval-auc:0.79877
# [76600]	train-auc:0.91294	eval-auc:0.79877
# [76800]	train-auc:0.91310	eval-auc:0.79878
# [77000]	train-auc:0.91326	eval-auc:0.79878
# [77200]	train-auc:0.91343	eval-auc:0.79878
# [77400]	train-auc:0.91359	eval-auc:0.79878
# [77600]	train-auc:0.91376	eval-auc:0.79879
# [77800]	train-auc:0.91394	eval-auc:0.79879
# [78000]	train-auc:0.91412	eval-auc:0.79880
# [78200]	train-auc:0.91428	eval-auc:0.79880
# [78400]	train-auc:0.91444	eval-auc:0.79880
# [78600]	train-auc:0.91461	eval-auc:0.79880
# [78800]	train-auc:0.91478	eval-auc:0.79880
# [79000]	train-auc:0.91495	eval-auc:0.79879
# [79200]	train-auc:0.91511	eval-auc:0.79879
# [79400]	train-auc:0.91529	eval-auc:0.79879
# [79600]	train-auc:0.91545	eval-auc:0.79878
# [79800]	train-auc:0.91561	eval-auc:0.79878
# [80000]	train-auc:0.91578	eval-auc:0.79879
# [80200]	train-auc:0.91595	eval-auc:0.79880
# [80400]	train-auc:0.91612	eval-auc:0.79879
# [80600]	train-auc:0.91629	eval-auc:0.79880
# [80800]	train-auc:0.91645	eval-auc:0.79880
# [81000]	train-auc:0.91662	eval-auc:0.79881
# [81200]	train-auc:0.91680	eval-auc:0.79881
# [81400]	train-auc:0.91696	eval-auc:0.79881
# [81600]	train-auc:0.91712	eval-auc:0.79881
# [81800]	train-auc:0.91729	eval-auc:0.79881
# [82000]	train-auc:0.91744	eval-auc:0.79882
# [82200]	train-auc:0.91761	eval-auc:0.79882
# [82400]	train-auc:0.91777	eval-auc:0.79882
# [82600]	train-auc:0.91794	eval-auc:0.79882
# [82800]	train-auc:0.91810	eval-auc:0.79882
# [83000]	train-auc:0.91826	eval-auc:0.79883
# [83200]	train-auc:0.91842	eval-auc:0.79883
# [83400]	train-auc:0.91858	eval-auc:0.79883
# [83600]	train-auc:0.91874	eval-auc:0.79883
# [83800]	train-auc:0.91891	eval-auc:0.79883
# [84000]	train-auc:0.91907	eval-auc:0.79883
# [84200]	train-auc:0.91922	eval-auc:0.79883
# [84400]	train-auc:0.91938	eval-auc:0.79883
# [84600]	train-auc:0.91955	eval-auc:0.79884
# [84800]	train-auc:0.91970	eval-auc:0.79884
# [85000]	train-auc:0.91985	eval-auc:0.79884
# [85200]	train-auc:0.92001	eval-auc:0.79884
# [85400]	train-auc:0.92018	eval-auc:0.79884
# [85600]	train-auc:0.92033	eval-auc:0.79884
# [85800]	train-auc:0.92050	eval-auc:0.79884
# [86000]	train-auc:0.92066	eval-auc:0.79884
# [86200]	train-auc:0.92082	eval-auc:0.79883
# [86400]	train-auc:0.92098	eval-auc:0.79883
# [86600]	train-auc:0.92113	eval-auc:0.79883
# [86800]	train-auc:0.92128	eval-auc:0.79884
# [87000]	train-auc:0.92144	eval-auc:0.79883
# [87200]	train-auc:0.92158	eval-auc:0.79884
# [87400]	train-auc:0.92175	eval-auc:0.79883
# [87600]	train-auc:0.92190	eval-auc:0.79884
# [87800]	train-auc:0.92205	eval-auc:0.79883
# [88000]	train-auc:0.92220	eval-auc:0.79883
# [88021]	train-auc:0.92222	eval-auc:0.79883
# Time elapsed: 4446.116664171219
# Fold AUC: 0.7988445579133884
# CPU times: user 1h 14min 9s, sys: 5.1 s, total: 1h 14min 14s
# Wall time: 1h 14min 6s

# %%
# %%time
params['eta'] = 0.01


start_time = time()
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].values[train_index], train[good_features].values[test_index]
        y_train, y_val = target[train_index], target[test_index]
        xgtrain = xgb.DMatrix(xgtrain, label = y_train ) 
        xgval = xgb.DMatrix(xgval, label = y_val ) 
        watchlist = [(xgtrain, 'train'), (xgval, 'eval')]
        clf = xgb.train(params, xgtrain, num_boost_round=10000, evals=watchlist, 
                verbose_eval=100, 
                early_stopping_rounds = 200)
        
        #preds = clf.predict(xgtest)
        ypred = clf.predict(xgval, ntree_limit=clf.best_ntree_limit)
        #y_oof[test_index] = ypred
        #preds_total += preds
        #np.save("preds_hist_"+str(i), preds)
        #p.save("oof_preds_hist_"+str(i), ypred)
        print('Time elapsed:', time()-start_time)
        #clf.save_model('xgb_gpu_hist_1812_2_fold_'+str(i)+'.model')
        del clf
        gc.collect()
        i +=1
        print('Fold AUC:', roc_auc_score(y_val, ypred))
        
        break
# Out:
# 1
# [0]	train-auc:0.75684	eval-auc:0.74114
# [100]	train-auc:0.78491	eval-auc:0.76299
# [200]	train-auc:0.79218	eval-auc:0.76740
# [300]	train-auc:0.80006	eval-auc:0.77176
# [400]	train-auc:0.80895	eval-auc:0.77676
# [500]	train-auc:0.81755	eval-auc:0.78116
# [600]	train-auc:0.82484	eval-auc:0.78477
# [700]	train-auc:0.83085	eval-auc:0.78738
# [800]	train-auc:0.83591	eval-auc:0.78906
# [900]	train-auc:0.84048	eval-auc:0.79052
# [1000]	train-auc:0.84436	eval-auc:0.79169
# [1100]	train-auc:0.84800	eval-auc:0.79270
# [1200]	train-auc:0.85152	eval-auc:0.79344
# [1300]	train-auc:0.85490	eval-auc:0.79407
# [1400]	train-auc:0.85808	eval-auc:0.79463
# [1500]	train-auc:0.86112	eval-auc:0.79512
# [1600]	train-auc:0.86395	eval-auc:0.79556
# [1700]	train-auc:0.86694	eval-auc:0.79590
# [1800]	train-auc:0.86973	eval-auc:0.79619
# [1900]	train-auc:0.87237	eval-auc:0.79647
# [2000]	train-auc:0.87486	eval-auc:0.79671
# [2100]	train-auc:0.87728	eval-auc:0.79698
# [2200]	train-auc:0.87959	eval-auc:0.79720
# [2300]	train-auc:0.88180	eval-auc:0.79735
# [2400]	train-auc:0.88408	eval-auc:0.79746
# [2500]	train-auc:0.88619	eval-auc:0.79768
# [2600]	train-auc:0.88816	eval-auc:0.79783
# [2700]	train-auc:0.89022	eval-auc:0.79804
# [2800]	train-auc:0.89241	eval-auc:0.79818
# [2900]	train-auc:0.89463	eval-auc:0.79820
# [3000]	train-auc:0.89667	eval-auc:0.79832
# [3100]	train-auc:0.89853	eval-auc:0.79833
# [3200]	train-auc:0.90051	eval-auc:0.79836
# [3300]	train-auc:0.90249	eval-auc:0.79843
# [3400]	train-auc:0.90439	eval-auc:0.79844
# [3500]	train-auc:0.90627	eval-auc:0.79846
# [3600]	train-auc:0.90803	eval-auc:0.79848
# [3700]	train-auc:0.90977	eval-auc:0.79852
# [3800]	train-auc:0.91165	eval-auc:0.79854
# [3900]	train-auc:0.91331	eval-auc:0.79852
# [3942]	train-auc:0.91397	eval-auc:0.79850
# Time elapsed: 212.70046758651733
# Fold AUC: 0.7985728088412014
# CPU times: user 3min 38s, sys: 3.31 s, total: 3min 41s
# Wall time: 3min 32s

# %%
# %%time
params['eta'] = 0.03


start_time = time()
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].values[train_index], train[good_features].values[test_index]
        y_train, y_val = target[train_index], target[test_index]
        xgtrain = xgb.DMatrix(xgtrain, label = y_train ) 
        xgval = xgb.DMatrix(xgval, label = y_val ) 
        watchlist = [(xgtrain, 'train'), (xgval, 'eval')]
        clf = xgb.train(params, xgtrain, num_boost_round=10000, evals=watchlist, 
                verbose_eval=100, 
                early_stopping_rounds = 100)
        
        #preds = clf.predict(xgtest)
        ypred = clf.predict(xgval, ntree_limit=clf.best_ntree_limit)
        #y_oof[test_index] = ypred
        #preds_total += preds
        #np.save("preds_hist_"+str(i), preds)
        #p.save("oof_preds_hist_"+str(i), ypred)
        print('Time elapsed:', time()-start_time)
        #clf.save_model('xgb_gpu_hist_1812_2_fold_'+str(i)+'.model')
        del clf
        gc.collect()
        i +=1
        print('Fold AUC:', roc_auc_score(y_val, ypred))
        
        break
# Out:
# 1
# [0]	train-auc:0.75684	eval-auc:0.74114
# [100]	train-auc:0.79963	eval-auc:0.77163
# [200]	train-auc:0.82433	eval-auc:0.78354
# [300]	train-auc:0.83969	eval-auc:0.78941
# [400]	train-auc:0.85126	eval-auc:0.79219
# [500]	train-auc:0.86071	eval-auc:0.79379
# [600]	train-auc:0.86889	eval-auc:0.79458
# [700]	train-auc:0.87669	eval-auc:0.79524
# [800]	train-auc:0.88416	eval-auc:0.79571
# [900]	train-auc:0.89045	eval-auc:0.79580
# [979]	train-auc:0.89508	eval-auc:0.79579
# Time elapsed: 60.63681197166443
# Fold AUC: 0.7958909365808279
# CPU times: user 1min 6s, sys: 3.36 s, total: 1min 9s
# Wall time: 1min

# %%
train[good_features].loc[[1,5,99]]
# Out:
#     AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 1                         0.0                         0.0
# 5                         0.0                         0.0
# 99                        NaN                         NaN
#
#     AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 1                         0.0                         0.0
# 5                         0.0                         0.0
# 99                        NaN                         NaN
#
#     AMT_REQ_CREDIT_BUREAU_YEAR  APARTMENTS_AVG  APARTMENTS_MEDI  \
# 1                          0.0          0.0959           0.0968
# 5                          1.0             NaN              NaN
# 99                         NaN          0.1361           0.1374
#
#     APARTMENTS_MODE  BASEMENTAREA_AVG  BASEMENTAREA_MEDI  ...  \
# 1            0.0924            0.0529             0.0529  ...
# 5               NaN               NaN                NaN  ...
# 99           0.0777            0.0761             0.0761  ...
#
#     total_credit_None  debt_credit_ratio_None  AGE_INT  ORGANIZATION_TYPE_cnt  \
# 1           1017400.5                0.000000       45                  10180
# 5            468445.5                0.512454       46                  19390
# 99                NaN                     NaN       61                  64648
#
#     region_id  prev_app_decision_days_max  \
# 1    0.003541                      -746.0
# 5    0.035792                       -82.0
# 99   0.026392                     -1105.0
#
#     prev_app_days_approved_decision_max  neighbors_target_mean_500  \
# 1                                -746.0                   0.040080
# 5                                -370.0                   0.032064
# 99                              -1105.0                   0.046092
#
#     neighbors_500_credit_downpayment_median  \
# 1                                -165012.75
# 5                                 -49896.00
# 99                                -66825.00
#
#     neighbors_500_DAYS_CREDIT_mean_median
# 1                                     NaN
# 5                                     NaN
# 99                                    NaN
#
# [3 rows x 1828 columns]

# %%
kf = StratifiedKFold(5, shuffle=True, random_state=1974)
i=1
for train_index, test_index in kf.split(train,target):
    #if i < 4:
        print(i)
        xgtrain, xgval = train[good_features].loc[train_index], train[good_features].loc[test_index]
        y_train, y_val = target[train_index], target[test_index]
        
        break
# Out:
# 1

# %%
xgtrain.head()
# Out:
#    AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 0                        0.0                         0.0
# 3                        NaN                         NaN
# 4                        0.0                         0.0
# 5                        0.0                         0.0
# 6                        0.0                         0.0
#
#    AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 0                        0.0                         0.0
# 3                        NaN                         NaN
# 4                        0.0                         0.0
# 5                        0.0                         0.0
# 6                        1.0                         0.0
#
#    AMT_REQ_CREDIT_BUREAU_YEAR  APARTMENTS_AVG  APARTMENTS_MEDI  \
# 0                         1.0          0.0247            0.025
# 3                         NaN             NaN              NaN
# 4                         0.0             NaN              NaN
# 5                         1.0             NaN              NaN
# 6                         2.0             NaN              NaN
#
#    APARTMENTS_MODE  BASEMENTAREA_AVG  BASEMENTAREA_MEDI  ...  \
# 0           0.0252            0.0369             0.0369  ...
# 3              NaN               NaN                NaN  ...
# 4              NaN               NaN                NaN  ...
# 5              NaN               NaN                NaN  ...
# 6              NaN               NaN                NaN  ...
#
#    total_credit_None  debt_credit_ratio_None  AGE_INT  ORGANIZATION_TYPE_cnt  \
# 0         865055.565                0.284122       25                  78832
# 3                NaN                     NaN       52                  78832
# 4         146250.000                0.000000       54                     97
# 5         468445.500                0.512454       46                  19390
# 6        4800811.500                0.224410       37                  78832
#
#    region_id  prev_app_decision_days_max  prev_app_days_approved_decision_max  \
# 0   0.018801                      -606.0                               -606.0
# 3   0.008019                      -181.0                               -181.0
# 4   0.028663                      -374.0                               -374.0
# 5   0.035792                       -82.0                               -370.0
# 6   0.035792                       -74.0                                -74.0
#
#    neighbors_target_mean_500  neighbors_500_credit_downpayment_median  \
# 0                   0.278557                                -58236.75
# 3                   0.034068                                -18000.00
# 4                   0.072144                                -78588.00
# 5                   0.032064                                -49896.00
# 6                   0.010020                               -163469.25
#
#    neighbors_500_DAYS_CREDIT_mean_median
# 0                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
#
# [5 rows x 1828 columns]

# %%
xgtrain['target'] = y_train
xgval['target'] = y_val

# %%
xgtrain.to_csv('../input/xgtrain.csv', index=False)
xgval.to_csv('../input/xgval.csv', index=False)
